# %%
#task1 

list = ["zometo","swingy","dominos","lapinos","makdons"]
list1 = iter(list)
# for i in list:
#     i = next(list1)
#     print(i)

# for i in list1:
#     print(i)

# %%
next(list1)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 next(list1)
#
# StopIteration:

# %%
#task2


def playlist_generator(playlist):
    for i in playlist:
        yield i

playlist = ["perfect","paro","shiba","high speed","on the way","merba"]
a = playlist_generator(playlist)

for i in a:
    print(i)
# Out:
# perfect
# paro
# shiba
# high speed
# on the way
# merba

# %%
#task3

foods = ["pizza", "burgger" , "sandwich" , "samosa" , "manturyan"]
for a,b in enumerate(foods,start=1):
    print(a,b)
# Out:
# 1 pizza
# 2 burgger
# 3 sandwich
# 4 samosa
# 5 manturyan

# %%
#task4

ipl_team = ["gt","rcb","srh","kkr","mi"]
team_scor = [5.2,9.9,6.5,8.4,4.2]



# for a,b in zip(ipl_team, team_scor):
#     print(a,b)

result = dict(zip(ipl_team,team_scor))
for team in result:
    print(f"team : {team} point : {result[team]}")
# Out:
# team : gt point : 5.2
# team : rcb point : 9.9
# team : srh point : 6.5
# team : kkr point : 8.4
# team : mi point : 4.2

# %%
# Task4

def order_id_generator():
    order_id = 1001

    while True:
        yield order_id
        order_id +=1

order = order_id_generator()

# for i in order:    infinity loop run here
#     print(i)

print(next(order))
print(next(order))
print(next(order))
print(next(order))
print(next(order))
print(next(order))
print(next(order))
print(next(order))
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
