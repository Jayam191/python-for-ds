# %%
#task1

item_price = 470
delivery_fee = 220
coupon_discount = 30

print(delivery_fee)
print(item_price)
print(coupon_discount)
# Out:
# 20
# 470
# 30

# %%
#task2

price = int(input("flipcart product price"))

if price > 1000:
    print("eligibal for free delivery")
else:
    print("not eligible for free delivery")
# Out:
# eligibal for free delivery

# %%
#task3  

# task1 is for printing tne itme price ,delivery fee, and coupne discount

''' task 2 checks if the price is greater than 1000 to determaine 
if free delivery applaies or if delivery chargis aplai'''
# Out:
# ' task 2 checks if the price is greater than 1000 to determaine \nif free delivery applaies or if delivery chargis aplai'

# %%
#task4

team_name = "rcb"
run_scors = 100
overs_played = 10

print(team_name)
print(run_scors)
print(overs_played)
# Out:
# rcb
# 100
# 10
