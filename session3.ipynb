# %%
#task1
age = 18
height = 175
name = "jayam"
spotify_account = True

print(age)
print(height)
print(name)
print(spotify_account)
# Out:
# 18
# 175
# jayam
# True

# %%
#task2

product_price = ["120" , "35.2", "459"]
a = float(product_price[0])
b = float(product_price[1])
c = float(product_price[2])

total = sum([a,b,c])

print(total)
# Out:
# 614.2

# %%
#task3

cricket_scor = str(input("cricket scor"))
cricket_scor = int(cricket_scor)
cricket_scor
if cricket_scor > 50:
    print("half century")
else:
    print("keep gaoing")
# Out:
# keep gaoing

# %%
#task4

is_premiuam = "True"

is_premiuam = (is_premiuam == "True")

print(is_premiuam)
print(type(is_premiuam))
# Out:
# True
# <class 'bool'>
