# %%
#task1 

import math

squreroot = math.sqrt(225)
squreroot
# Out:
# 15.0

# %%
#task2
import os 

os.mkdir("mydownloads")

print(os.path.abspath("mydownloads"))
# Out:
# d:\tops\python for ds\mydownloads

# %%
#task3

from datetime import datetime


curent_time = datetime.now()

formt_time = curent_time.strftime("%d-%m-%Y  %H:%M:%S")
print(formt_time)
# Out:
# 01-08-2026  20:26:52

# %%
#task4

import playlist_util

playlist1 = []

playlist_util.playlist_songs(playlist1,"perfect")
playlist_util.playlist_songs(playlist1,"isqu e dard ki ibadat")
playlist_util.playlist_songs(playlist1,"kaho na kaho")

playlist1
# Out:
# ['perfect', 'isqu e dard ki ibadat', 'kaho na kaho']

# %%
#task5

import requests

print(requests.__version__)
# Out:
# 2.33.1
