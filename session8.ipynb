# %%
#task1

for i in range(5):
    favirit_food_app = input("enter a app namae :- ")
    print(favirit_food_app)
# Out:
# apple
# mango
# banana
# graps
# kivi

# %%
#task2

list = [8000,5555,11000,6000,10010]

for i in list:
    if i >10000:
        print(i)
        break
    i+=1
# Out:
# 11000

# %%
#task3

ipl = ["gujarat","bangluru","myteam","rajesthan","delhi"]

for i in ipl:
    if len(i)>6:
        print(i)
# Out:
# gujarat
# bangluru
# rajesthan

# %%
#task4

song_duration = [120,129,150,79,240]

for index,duration in enumerate(song_duration,start=1):
    print(f"song {index} : {duration} second")
# Out:
# song 1 : 120 second
# song 2 : 129 second
# song 3 : 150 second
# song 4 : 79 second
# song 5 : 240 second

# %%
#task5

price = [200,800,0,55,1999,900]
total = 0
for i in price:
    if i==0:
        continue
    total = total +i
    if total > 2000:
        print(total)
        break
# Out:
# 3054
