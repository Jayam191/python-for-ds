# %%
#task1 

playlist_id = [ 12, 4,6,7]
playlist_id
# Out:
# [12, 4, 6, 7]

# %%
#task2

playlist_id.append(500)
playlist_id.append(69)
print(playlist_id)

playlist_id.extend([99 , 100])
print(playlist_id)
# Out:
# [12, 4, 6, 7, 500, 69]
# [12, 4, 6, 7, 500, 69, 99, 100]

# %%
#task3

print(playlist_id.pop())
print(playlist_id)
# Out:
# 100
# [12, 4, 6, 7, 500, 69, 99]

# %%
#task4

insta_filter = ("glossy", "glossier", "pleasantX1", "urban glitch")
insta_filter.replace("glossy","dark")

#it is inmutable 
# attributerror : "tuple" object has no attribute " replace"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 #task4
#       2
#       3 insta_filter = ("glossy", "glossier", "pleasantX1", "urban glitch")
# ----> 4 insta_filter.replace("glossy","dark")
#
# AttributeError: 'tuple' object has no attribute 'replace'

# %%
#task5

zometo_order = ["pizza" , "burger" , "sprite"]  # list is ude because it not fixt we can replace the order

ipl_team = ("gt", "rcb" , "srh", "kkr", "csk", "mi") # tuple is use here becaus it is fixed 

print("recent order : " , zometo_order)
print("ipl team : " , ipl_team)
# Out:
# recent order :  ['pizza', 'burger', 'sprite']
# ipl team :  ('gt', 'rcb', 'srh', 'kkr', 'csk', 'mi')
