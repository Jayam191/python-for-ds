# %%
#task1

music_time = int(input("enter a time in minute"))

if music_time >120:
    print("you are true music lover")
else:
    print("keep gaoing")
# Out:
# keep gaoing

# %%
#task2

zometo_order = int(input("enter a total amout:-"))
if zometo_order >300:
    print("you are eligibal for free delivery ")
else:
    print("you are not eligibal for free delivery")
# Out:
# you are eligibal for free delivery

# %%
#task3 

flipkart_totalamount = int(input("enter a total amount :-"))
if flipkart_totalamount > 2000:
    print("you get 10% discount ")
elif flipkart_totalamount > 1000:
    print("you get 10% discount ")
else:
    print("you can't get discount")
# Out:
# you can't get discount

# %%
#task4

point = int(input("enter a point"))

if point<800:
    if point>500:
        print("top perfomans")
    else:
        print("keep going")
else:
    print("champion")
# Out:
# keep going
