# %%
#task1

file = open("playlist.txt","w")
file.write("tum jo aye jundgi me ")
file.write("\nkahona kahon")
file.write("\ndil diya galla")
file.write("\nham tum milne ko milte rahe")
file.write("\nperfect")
file.close()

# %%
#task2


# file = open("playlist.txt","r")
# content = file.read()
# print(content.upper())


# file = open("playlist.txt","r")
# file.readlines()


file = open("playlist.txt","r")
for song in file:
    print(song.strip().upper())
# Out:
# ['tum jo aye jundgi me \n',
#  'kahona kahon\n',
#  'dil diya galla\n',
#  'ham tum milne ko milte rahe\n',
#  'perfect']

# %%
#task3

import csv

with open("match_score.csv","w",newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["match_id", "team1", "team2", "winner"])
    writer.writerow([1,"rcb","gt","gt"])
    writer.writerow([1,"rcb","srh","rcb"])

# with open("match_score.csv","r",newline="") as file:
#     reader = csv.reader(file)
#     for i in reader:
#         print(i)
# Out:
# ['match_id', 'team1', 'team2', 'winner']
# ['1', 'rcb', 'gt', 'gt']
# ['1', 'rcb', 'srh', 'rcb']

# %%
#task4

import json

# movie_list = [
#     {"tital" : "kalki",
#     "year"  : 2023,
#     "rating" : 9.8}
#     ,
#     {"tital" : "kgf chapter 2",
#      "year": 2022,
#      "rating": 9.9}
#     ,
#     {"tital" : "salar",
#      "year": 2025,
#      "rating": 9.5}
# ]

# with open("movie_list.json","w") as file:
#     json.dump(movie_list,file)


with open("movie_list.json","r") as file:
    # print(json.load(file))
    movies = json.load(file)
    for moive in movies:
        print(moive)
# Out:
# {'tital': 'kalki', 'year': 2023, 'rating': 9.8}
# {'tital': 'kgf chapter 2', 'year': 2022, 'rating': 9.9}
# {'tital': 'salar', 'year': 2025, 'rating': 9.5}

# %%
#task5

from pathlib import Path

path_exist = Path("my_fav_app.json")

if path_exist.exists():
    print("file already have it")
else:
    apps = [
        {
            "name" : "instagram",
            "category" : "social media"
        }
        ,
        {
            "name" : "snap chat",
            "category" : "chat perpose"
        }
        ,
        {
            "name" : "spotify",
            "category" : "songs"
        }
    ]

    with open("my_fav_app.json","w") as file:
        favapp = json.dump(apps , file)
# Out:
# file already have it
