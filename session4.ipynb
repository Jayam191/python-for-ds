# %%
#task1

a = "Flipkart-Sale2024"
a = a.lower()
a = a.replace("-"," ")
print(a)
# Out:
# flipkart sale2024

# %%
#task2

a = " OnePlus nord-ce 3 "
a = a.strip().upper().replace("-" , ",")
a
# Out:
# 'ONEPLUS NORD,CE 3'

# %%
#task3

def  split_product_code(product_code):
    return product_code.split("-")

a = "ZOMATO-FOOD-2024"
b = split_product_code(a)
b
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %%
#task4

str = "Spotify_Premium_Offe"

str = str[8:15]
str
# Out:
# 'Premium'

# %%
#task5

product = 'Myntra Shirt'
price = 799.5

print(f"Deel : {product} ia available at ${price} only")
# Out:
# Deel : Myntra Shirt ia available at $799.5 only
