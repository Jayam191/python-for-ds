# %%
#task 1

import requests

url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    for post in data[:5]:
        print(f"post id :- {post['id']} post title :- {post['title']}")
# Out:
# post id :- 1 post title :- sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# post id :- 2 post title :- qui est esse
# post id :- 3 post title :- ea molestias quasi exercitationem repellat qui ipsa sit aut
# post id :- 4 post title :- eum et est occaecati
# post id :- 5 post title :- nesciunt quas odio

# %%
# task 2

import json 

restaurants = {
    "name" : "patang",
    "loacation" : "ahmedabad",
    "rating" : 4.5
}

json_data = json.dumps(restaurants)
json_data
# Out:
# '{"name": "patang", "loacation": "ahmedabad", "rating": 4.5}'

# %%
#task 3

import requests

url ="https://jsonplaceholder.typicode.com/posts"

data = {
    "title" : "my playlist",
    "user id" : 2,
    "body" : "this is my playlist" 
}

response = requests.post(url , json=data)
print("statuse_code :-",response.status_code)
print("new data :- ",response.json())
# Out:
# statuse_code :- 201
# new data :-  {'title': 'my playlist', 'user id': 2, 'body': 'this is my playlist', 'id': 101}

# %%
#task 4 

url = "https://jsonplaceholder.typicode.com/posts"

param = {
    "userId" :2
}

response = requests.get(url , params=param)

print("staus_code :-",response.status_code)
data = response.json()
print("data :-",data)

for post in data:
    print(post['id'])
# Out:
# staus_code :- 200
# ...

# %%
#task 5

import requests


url = "https://httpbin.org/get"

headers = {
    "Authorization": "Bearer abc123",
    "X-My-Header": "Hello"
}

response = requests.get(url, headers=headers)

print("Status code:", response.status_code)
# Out:
# Status code: 200
