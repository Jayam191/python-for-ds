# %%
#task1

insta_follower = {
    "jayam671" : 560,
    "ronaldo" : "400M",
    "sahid_kapur" : "50.6"

}

insta_follower
# Out:
# {'jayam671': 560, 'ronaldo': '400M', 'sahid_kapur': '50.6'}

# %%
#task2

insta_follower["virat"]= "220M"
print(insta_follower)

insta_follower["jayam671"] = 570
print(insta_follower)

del insta_follower["ronaldo"]
print(insta_follower)
# Out:
# {'jayam671': 560, 'ronaldo': '400M', 'sahid_kapur': '50.6', 'virat': '220M'}
# {'jayam671': 570, 'ronaldo': '400M', 'sahid_kapur': '50.6', 'virat': '220M'}
# {'jayam671': 570, 'sahid_kapur': '50.6', 'virat': '220M'}

# %%
#task3

zometo_order = {
    "duble chissy pizza"  : 220,
    "sprit" : 20,
    "burger" : 199,
    "waffal" : 299,
    "cake" : 300
}

for item,price in zometo_order.items():
    if price>=200:
        print(item,price)
# Out:
# duble chissy pizza 220
# waffal 299
# cake 300

# %%
#task4

flipkart_user = {"jayam" , "raviraj " , "fenil" , "denisha" , "mansi"}
myntra_user = { "susant" , "jayam" , "mahi" , "mansi", "urvish"}

common_username = flipkart_user.intersection(myntra_user)

print(common_username)
# Out:
# {'jayam', 'mansi'}

# %%
#task5

def get_unique_artist(playlist1 , playlist2):
    risult= playlist1.union(playlist2)
    return risult

playlist1 = {"arjit" , "kk" , "sonunigam" , "atifaslam"}

playlist2 = {"kk", "yoyo", "nusratfatealikhan", "sunita chauhan"}

risult = get_unique_artist(playlist1, playlist2)

print(risult)
# Out:
# {'kk', 'arjit', 'sunita chauhan', 'yoyo', 'atifaslam', 'nusratfatealikhan', 'sonunigam'}
